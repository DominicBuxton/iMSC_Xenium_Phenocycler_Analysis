# %% [markdown]
# General testing stuff

# %% [markdown]
# Current is landmark systematisation

# %%
import napari
import spatialdata 
import sopa
import napari_spatialdata
import spatialdata_plot
# Out:
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\xarray_schema\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\spatialdata\_core\query\relational_query.py:530: FutureWarning: functools.partial will be a method descriptor in future Python versions; wrap it in enum.member() if you want to preserve the old behavior
#   left = partial(_left_join_spatialelement_table)
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\spatialdata\_core\query\relational_query.py:531: FutureWarning: functools.partial will be a method descriptor in future Python versions; wrap it in enum.member() if you want to preserve the old behavior
#   left_exclusive = partial(_left_exclusive_join_spatialelement_table)
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\spatialdata\_core\query\relational_query.py:532: FutureWarning: functools.partial will be a method descriptor in future Python versions; wrap it in enum.member() if you want to preserve the old behavior
#   inner = partial(_inner_join_spatialelement_table)
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\spatialdata\_core\query\relational_query.py:533: FutureWarning: functools.partial will be a method descriptor in future Python versions; wrap it in enum.member() if you want to preserve the old behavior
#   right = partial(_right_join_spatialelement_table)
# d:\Dom\Virtual_Environments\napari_registration_project\.venv\Lib\site-packages\spatialdata\_core\query\relational_query.py:534: FutureWarning: functools.partial will be a method descriptor in future Python versions; wrap it in enum.member() if you want to preserve the old behavior
#   right_exclusive = partial(_right_exclusive_join_spatialelement_table)

# %%
xenpath = "D:/Dom/Fibrosis project/4th year data/pheno_xen_fullres_images/roi1/morphology_focus_scaledX_dapi.ome.tif"
phenopath = "D:/Dom/Fibrosis project/4th year data/pheno_xen_fullres_images/roi1/pheno_C12.ome.tif"

xen_image = sopa.io.ome_tif(xenpath)
pheno_image = sopa.io.ome_tif(phenopath)

# %%
from napari_spatialdata import Interactive
Interactive([xen_image, pheno_image]).run()
# Out:
# 2025-11-25 12:33:56.094 | WARNING  | napari_spatialdata._viewer:__init__:57 - Due to Shift-L being used as shortcut in napari, it is being deprecated and might not link a new layer to an existing SpatialData object in the viewer. Please use ⌘-L on MacOS or else Ctrl-L.
# 2025-11-25 12:34:04.309 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:06.328 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:06.333 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:10.201 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:10.207 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:11.270 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:11.793 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:11.798 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:15.105 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:15.107 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:16.449 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:16.453 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:19.841 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:19.847 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:20.875 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:20.877 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:24.300 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:24.304 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-11-25 12:34:24.305 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.

# %%
import pandas as pd
import numpy as np
from spatialdata.models import PointsModel
from spatialdata.transformations import Identity

# Read your CSV file
landmarks_df = pd.read_csv("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/Landmark csvs/gt_xen_roi1.csv")
pheno_landmarks_df = pd.read_csv("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/Landmark csvs/gt_pheno_roi1.csv")

# Extract coordinates (axis-1 = x, axis-2 = y)
# SpatialData expects coordinates in (y, x) order for 2D points
coords = landmarks_df[['axis-2', 'axis-1']].values
pheno_coords = pheno_landmarks_df[['axis-2', 'axis-1']].values

# Create a DataFrame in the format expected by PointsModel
# PointsModel expects columns: ['x', 'y'] or ['z', 'y', 'x'] for 3D
points_df = pd.DataFrame({
    'y': landmarks_df['axis-1'].values,
    'x': landmarks_df['axis-2'].values
})

pheno_points_df = pd.DataFrame({
    'y': pheno_landmarks_df['axis-1'].values,
    'x': pheno_landmarks_df['axis-2'].values
})

# Create the points element with transformation to global coordinate system
points_element = PointsModel.parse(
    points_df,
    transformations={"global": Identity()}
)

pheno_points_element = PointsModel.parse(
    pheno_points_df,
    transformations={"global": Identity()}
)

# Add to your xen_image SpatialData object
xen_image.points['xen_landmarks'] = points_element
pheno_image.points['pheno_landmarks'] = pheno_points_element

# %%
import pandas as pd
import numpy as np
from spatialdata.models import PointsModel
from spatialdata.transformations import Identity

# Read your CSV file
landmarks_df = pd.read_csv("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/Landmark csvs/50gt_xen_roi1.csv")
pheno_landmarks_df = pd.read_csv("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/Landmark csvs/50gt_pheno_roi1.csv")

# Extract coordinates (axis-1 = x, axis-2 = y)
# SpatialData expects coordinates in (y, x) order for 2D points
coords = landmarks_df[['axis-0', 'axis-1']].values
pheno_coords = pheno_landmarks_df[['axis-0', 'axis-1']].values

# Create a DataFrame in the format expected by PointsModel
# PointsModel expects columns: ['x', 'y'] or ['z', 'y', 'x'] for 3D
points_df = pd.DataFrame({
    'y': landmarks_df['axis-0'].values,
    'x': landmarks_df['axis-1'].values
})

pheno_points_df = pd.DataFrame({
    'y': pheno_landmarks_df['axis-0'].values,
    'x': pheno_landmarks_df['axis-1'].values
})

# Create the points element with transformation to global coordinate system
points_element = PointsModel.parse(
    points_df,
    transformations={"global": Identity()}
)

pheno_points_element = PointsModel.parse(
    pheno_points_df,
    transformations={"global": Identity()}
)

# Add to your xen_image SpatialData object
xen_image.points['xen_landmarks'] = points_element
pheno_image.points['pheno_landmarks'] = pheno_points_element

# %%
#registration calculation
from spatialdata.transformations import (
    align_elements_using_landmarks,
    get_transformation_between_landmarks,
)

affine = get_transformation_between_landmarks(
    references_coords=xen_image["xen_landmarks"], moving_coords=pheno_image["pheno_landmarks"]
)
affine
affine = align_elements_using_landmarks(
    references_coords=xen_image["xen_landmarks"], 
    moving_coords=pheno_image["pheno_landmarks"],
    reference_element=xen_image[list(xen_image.images.keys())[0]],
    moving_element=pheno_image["pheno_C12"],
    reference_coordinate_system="global",
    moving_coordinate_system="global",
    new_coordinate_system="aligned",
)
affine
# Out:
# Sequence
#     Identity
#     Affine (x, y -> x, y)
#         [ 9.68049924e-01 -7.17873826e-03  5.74573359e+02]
#         [ 0.00717874  0.96804992 -5.06274547]
#         [0. 0. 1.]

# %%
xen_image.write("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/aligned objects/gt_xen.zarr")
pheno_image.write("D:/Dom/Fibrosis project/4th year data/xen_pheno_registration/systematising landmarks/aligned objects/gt_pheno.zarr")

xen_image.write_transformations()
pheno_image.write_transformations()
